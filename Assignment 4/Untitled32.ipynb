# %%
# !pip install selenium

# %%
#Imports
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,ElementNotInteractableException
 #Importing Exception
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import re
import requests
from selenium.webdriver.support import expected_conditions as EC

# %%
Q-1

# %%
driver= webdriver.Chrome()
driver.maximize_window()
#chrome

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/')
time.sleep(2)
#open url

# %%
Search = driver.find_element(By.XPATH, '//input[@class="cdx-text-input__input"]' )
Search.send_keys( 'List of most-viewed YouTube videos')
#Search the above topic

# %%
Search_click= driver.find_element(By.XPATH, '//button[@class="cdx-button cdx-button--action-default cdx-button--weight-normal cdx-button--size-medium cdx-button--framed cdx-search-input__end-button"]')
Search_click.click()
#click the search

# %%
Rank= []
Name= []
Artist= []
Upload_date= []
Views= []
#create empty fields

# %%
name = driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers sort-under col3center col4right jquery-tablesorter"]/tbody/tr/td')

for i in name:
    Name.append(i.text)
    
    
artists=  driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers sort-under col3center col4right jquery-tablesorter"]/tbody/tr/td[2]')
for i in artists:
    Artist.append(i.text)
    
    
upload_date= driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers sort-under col3center col4right jquery-tablesorter"]/tbody/tr/td[4]')
for i in upload_date:
    Upload_date.append(i.text)
    
    
views= driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers sort-under col3center col4right jquery-tablesorter"]/tbody/tr/td[3]')
for i in views:
    Views.append(i.text)
    
#Let's create a function to get the Match details

# %%
import pandas as pd

# %%
You_tube_videos=pd.DataFrame({})
You_tube_videos['Video Name']=Name[0:30]
You_tube_videos['Artist']=Artist[0:30]
You_tube_videos['Upload Date']=Upload_date[0:30]
You_tube_videos['Views (Billions)']=Views[0:30]
You_tube_videos
#let's create dataframe
# Out:
#                                            Video Name  \
# 0                               "Baby Shark Dance"[7]
# 1         Pinkfong Baby Shark - Kids' Songs & Stories
# 2                                               14.32
# 3                                       June 17, 2016
# 4                                                 [A]
# 5                                     "Despacito"[10]
# 6                                          Luis Fonsi
# 7                                                8.41
# 8                                    January 12, 2017
# 9                                                 [B]
# 10                         "Johny Johny Yes Papa"[18]
# 11  LooLoo Kids - Nursery Rhymes and Children's Songs
# 12                                               6.89
# 13                                    October 8, 2016
# 14
# 15                                    "Bath Song"[19]
# 16                         Cocomelon - Nursery Rhymes
# ...

# %%
Q-2

# %%
driver= webdriver.Chrome()
driver.maximize_window()

# %%
driver.get('https://www.bcci.tv/.')
time.sleep(2)

# %%
Search= driver.find_element(By.XPATH, '/html/body/header/div[1]/div/button[1]/img')
Search.click()

# %%
Select= driver.find_element(By.XPATH, '//input[@class="form-control border rounded-pill"]')
Select.send_keys('International fixtures')

# %%
Search_click= driver.find_element(By.XPATH, '/html/body/header/div[2]/form/div/div/div/span[2]/button')
Search_click.click()

# %%
Fixture= driver.find_element(By.XPATH, '/html/body/header/div[3]/div[2]/ul/div[1]/a[2]')
Fixture.click()

# %%
Series=[]
Date=[] 
Time=[]
Place=[]

# %%
series= driver.find_elements(By.XPATH, '//div[@class="match-card-middle d-flex"]')
for i in series:
    Series.append(i.text)
    

    
date= driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')
for i in date:
    Date.append(i.text)
    
time= driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')
for i in time:
    Time.append(i.text)
    
place= driver.find_elements(By.XPATH, '//span[@class="ng-binding ng-scope"]')
for i in place:
    Place.append(i.text)

# %%
IF_ICC=pd.DataFrame({})
IF_ICC['Series']=Series
IF_ICC['Date']=Date
IF_ICC['Time']=Time
IF_ICC['Place']=Place
IF_ICC
# Out:
#                             Series           Date         Time  \
# 0                   India\nIreland   5 JUNE, 2024  8:00 PM IST
# 1                  India\nPakistan   9 JUNE, 2024  8:00 PM IST
# 2  United States Of America\nIndia  12 JUNE, 2024  8:00 PM IST
# 3                    Canada\nIndia  15 JUNE, 2024  8:00 PM IST
# 4                  Zimbabwe\nIndia   6 JULY, 2024  8:00 PM IST
# 5                  Zimbabwe\nIndia   7 JULY, 2024  8:00 PM IST
# 6                  Zimbabwe\nIndia  10 JULY, 2024  8:00 PM IST
# 7                  Zimbabwe\nIndia  13 JULY, 2024  8:00 PM IST
# 8                  Zimbabwe\nIndia  14 JULY, 2024  8:00 PM IST
#
#                                                Place
# 0       Nassau County International Cricket Stadium,
# 1       Nassau County International Cricket Stadium,
# 2       Nassau County International Cricket Stadium,
# 3  Central Broward Park & Broward County Stadium,...
# 4                                Harare Sports Club,
# ...

# %%
Q-8

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
driver.get('https://archive.ics.uci.edu/')
time.sleep(2)

# %%
dataset=driver.find_element(By.XPATH, "/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]")
driver.get(dataset.get_attribute('href'))

# %%
Dataset_Name=[] 
Data_Type=[]
Task=[] 
Attribute_Type=[] 
No_of_Instances=[] 
No_of_Attribute=[] 
Year=[]

# %%
Expand= driver.find_element(By.XPATH, '//span[@class="swap-on text-primary-content"]')
Expand.click()

# %%
Name= driver.find_elements(By.XPATH, '//h2[@class="truncate text-primary"]')
for i in Name:
    Dataset_Name.append(i.text)
    
type= driver.find_elements(By.XPATH, '//div[@class="flex flex-col gap-1"]/div/div/div/div/div[2]/span')
for i in type:
    Data_Type.append(i.text)
    
task= driver.find_elements(By.XPATH, '//div[@class="flex flex-col gap-1"]/div/div/div/div/div/span')
for i in task:
    Task.append(i.text)
    
    

    

    
    

    
attribute= driver.find_elements(By.XPATH, '//tbody[@class="border"]/tr/td[2]')
for i in attribute:
    Attribute_Type.append(i.text)
    
    
instances= driver.find_elements(By.XPATH, '//div[@class="flex flex-col gap-1"]/div/div/div/div/div[3]/span')
for i in instances:
    No_of_Instances.append(i.text)
    
    
attribute= driver.find_elements(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[4]/span')
for i in attribute:
    No_of_Attribute.append(i.text)
    
    
year= driver.find_elements(By.XPATH, '//table[@class="col-span-full my-2 table sm:col-start-2"]/tbody/tr/td[3]')
for i in year:
    Year.append(i.text)

# %%
print(Attribute_Type)
# Out:
# ['Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer', 'Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer', 'Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer', 'Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer', 'Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer']

# %%
print(No_of_Instances)
# Out:
# ['150 Instances', '150 Instances', '150 Instances', '13.61K Instances', '303 Instances', '3.81K Instances', '48.84K Instances', '900 Instances', '569 Instances', '178 Instances', '4.9K Instances', '1 Instances', '150 Instances', '13.61K Instances', '303 Instances', '3.81K Instances', '48.84K Instances', '900 Instances', '569 Instances', '178 Instances', '4.9K Instances', '1 Instances', '150 Instances', '13.61K Instances', '303 Instances', '3.81K Instances', '48.84K Instances', '900 Instances', '569 Instances', '178 Instances', '4.9K Instances', '1 Instances']

# %%
UCI_ML=pd.DataFrame({})
UCI_ML['Dataset Name']=Dataset_Name 
UCI_ML['Attribute Type']=Attribute_Type
UCI_ML['No of Instances']=No_of_Instances
UCI_ML['No of Attribute']= No_of_Attribute
UCI_ML['Year']=Year
UCI_ML
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[381], line 4
#       2 UCI_ML['Dataset Name']=Dataset_Name
#       3 UCI_ML['Attribute Type']=Attribute_Type
# ----> 4 UCI_ML['No of Instances']=No_of_Instances
#       5 UCI_ML['No of Attribute']= No_of_Attribute
#       6 UCI_ML['Year']=Year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# ...

# %% [markdown]
# # Q-6

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
time.sleep(2)

# %%
Book_Name=[] 
Author_Name=[] 
Volumes_Sold=[]
Publisher=[] 
Genre=[]

# %%
name= driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in name:
    Book_Name.append(i.text)
    
    
Author= driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in Author:
    Author_Name.append(i.text)
    
Volumes= driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in Volumes:
    Volumes_Sold.append(i.text)
    
publisher= driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in publisher:
    Publisher.append(i.text)
    
genre= driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in genre:
    Genre.append(i.text)

# %%
print(Book_Name)
# Out:
# ['Da Vinci Code,The', 'Harry Potter and the Deathly Hallows', "Harry Potter and the Philosopher's Stone", 'Harry Potter and the Order of the Phoenix', 'Fifty Shades of Grey', 'Harry Potter and the Goblet of Fire', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Prisoner of Azkaban', 'Angels and Demons', "Harry Potter and the Half-blood Prince:Children's Edition", 'Fifty Shades Darker', 'Twilight', 'Girl with the Dragon Tattoo,The:Millennium Trilogy', 'Fifty Shades Freed', 'Lost Symbol,The', 'New Moon', 'Deception Point', 'Eclipse', 'Lovely Bones,The', 'Curious Incident of the Dog in the Night-time,The', 'Digital Fortress', 'Short History of Nearly Everything,A', 'Girl Who Played with Fire,The:Millennium Trilogy', 'Breaking Dawn', 'Very Hungry Caterpillar,The:The Very Hungry Caterpillar', 'Gruffalo,The', "Jamie's 30-Minute Meals", 'Kite Runner,The', 'One Day', 'Thousand Splendid Suns,A', "Girl Who Kicked the Hornets' Nest,The:Millennium Trilogy", "Time Traveler's Wife
# ...

# %%
print(Author_Name)
# Out:
# ['Brown, Dan', 'Rowling, J.K.', 'Rowling, J.K.', 'Rowling, J.K.', 'James, E. L.', 'Rowling, J.K.', 'Rowling, J.K.', 'Rowling, J.K.', 'Brown, Dan', 'Rowling, J.K.', 'James, E. L.', 'Meyer, Stephenie', 'Larsson, Stieg', 'James, E. L.', 'Brown, Dan', 'Meyer, Stephenie', 'Brown, Dan', 'Meyer, Stephenie', 'Sebold, Alice', 'Haddon, Mark', 'Brown, Dan', 'Bryson, Bill', 'Larsson, Stieg', 'Meyer, Stephenie', 'Carle, Eric', 'Donaldson, Julia', 'Oliver, Jamie', 'Hosseini, Khaled', 'Nicholls, David', 'Hosseini, Khaled', 'Larsson, Stieg', 'Niffenegger, Audrey', 'McEwan, Ian', 'Fielding, Helen', 'Clarkson, Jeremy', 'Bernieres, Louis de', 'Kay, Peter', 'Martel, Yann', 'Stephenson, Pamela', 'Pelzer, Dave', 'Donaldson, Julia', 'McCourt, Frank', 'Faulks, Sebastian', 'Pullman, Philip', 'Mosse, Kate', 'Rowling, J.K.', 'Stockett, Kathryn', 'Parsons, Tony', 'Golden, Arthur', 'McCall Smith, Alexander', 'Hislop, Victoria', 'Ahern, Cecelia', 'McKeith, Gillian', 'Zafon, Carlos Ruiz', 'Rowling, J.K.', 'Grisham
# ...

# %%
Novel=pd.DataFrame({})
Novel['Book Name']=Book_Name
Novel['Author Name']= Author_Name
Novel['Volumes Sold']=Volumes_Sold
Novel['Publisher']=Publisher
Novel['Genre']=Genre
Novel
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q-5

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
driver.get('https://www.billboard.com/')
time.sleep(2)

# %%
Select= driver.find_element(By.XPATH, '/html/body/div[3]/header/div/div[3]/div/nav/ul/li[1]/a')
Select.click()

# %%
Song_Name=[]
Artist_Name=[] 
Last_Week_Rank=[] 
Peak_Rank=[]
Weeks_on_Board=[]

# %%
name= driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3')
for i in name:
    Song_Name.append(i.text)
    
    
    
Artist= driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/span')
for i in Artist:
    Artist_Name.append(i.text)
    
    
rank= driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[4]/span')
for i in rank:
    Last_Week_Rank.append(i.text)
    
    
peak= driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[5]/span')
for i in peak:
    Peak_Rank.append(i.text)
    
    
weeks= driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[6]/span')
for i in weeks:
    Weeks_on_Board.append(i.text)

# %%
print(Last_Week_Rank)

# %%
print(Artist_Name)
# Out:
# ['Future, Metro Boomin, Travis Scott & Playboi Carti', 'Benson Boone', 'Teddy Swims', 'Hozier', 'Future, Metro Boomin & Travis Scott', 'Jack Harlow', 'Future & Metro Boomin', 'Future, Metro Boomin & The Weeknd', 'Ariana Grande', 'Beyonce', '¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti', 'Future & Metro Boomin', 'Olivia Rodrigo', 'Zach Bryan Featuring Kacey Musgraves', 'Taylor Swift', 'Tate McRae', 'Noah Kahan', 'Tyla', 'Future & Metro Boomin', 'Djo', 'Doja Cat', 'SZA', 'Future & Metro Boomin', 'Luke Combs', 'SZA', 'Future & Metro Boomin', 'Sexyy Red', 'Flo Milli', '21 Savage', '4Batz Featuring Drake', 'Bryson Tiller', 'Future & Metro Boomin', 'Muni Long', 'Sabrina Carpenter', 'Future & Metro Boomin', 'Morgan Wallen Featuring Eric Church', 'Future, Metro Boomin & Rick Ross', 'HARDY', 'Future & Metro Boomin', 'Future & Metro Boomin', 'Dua Lipa', 'Doja Cat', 'Cardi B', 'Benson Boone', 'Justin Timberlake', 'Taylor Swift', 'Chayce Beckham', 'GloRilla', 'Luke Combs', 'Park
# ...

# %%
TOP_100_SONGS=pd.DataFrame({})
TOP_100_SONGS['Song_name']=Song_Name[:100]
TOP_100_SONGS['Artist_name']=Artist_Name[:100]
TOP_100_SONGS['Last_week_rank']=Last_Week_Rank[:100]
TOP_100_SONGS['Peak_rank']=Peak_Rank[:100]
TOP_100_SONGS['Weeks_on_board']= Weeks_on_Board[:100]
TOP_100_SONGS
# Out:
#                 Song_name                                        Artist_name  \
# 0               Like That              Future, Metro Boomin & Kendrick Lamar
# 1               Type Shit                                                  -
# 2        Beautiful Things                                                  1
# 3            Lose Control                                                  1
# 4               Too Sweet  Future, Metro Boomin, Travis Scott & Playboi C...
# ..                    ...                                                ...
# 95             La Victima                                                  1
# 96        Tucson Too Late                                         Luke Combs
# 97             Empire Now                                                 18
# 98  Girl I've Always Been                                                  2
# 99              Outskirts                                                 53
#
#    Last_week_rank Peak_rank Weeks_on_board
# ...

# %% [markdown]
# # Q-4

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
driver.get('https://github.com/')
time.sleep(2)

# %%
Open= driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
Open.click()

# %%
Trending= driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
try:
    Trending.click()
except ElementNotInteractableException:
    driver.get(Trending.get_attribute('href'))

# %%
Repository_Title=[]
Repository_Description=[] 
Contributors_Count=[] 
Language_Used=[]

# %%
title= driver.find_elements(By.XPATH, '//h2[@class="h3 lh-condensed"]/a')
for i in title:
    Repository_Title.append(i.text)
    
    
desc= driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in desc:
    try:
        Repository_Description.append(i.text)
    except:
        Repository_Description.append("_")
        
    
    
    
count= driver.find_elements(By.XPATH, '//span[@class="d-inline-block float-sm-right"]')
for i in count:
    try:
        Contributors_Count.append(i.text)
    except:
        Contributors_Count.append("-")
        
Language= driver.find_elements(By.XPATH, '//span[@class="d-inline-block ml-0 mr-3"]/span[2]')
for i in Language:
    try:
        Language_Used.append(i.text)
    except:
        Language_Used.append("_")

# %%
Repositoriy=pd.DataFrame({})
Repositoriy['Repository Title']=Repository_Title[0:24]
Repositoriy['Repository Description']=Repository_Description[0:24]
Repositoriy['Contributors Count']=Contributors_Count[0:24]
Repositoriy['Language Used']=Language_Used[0:24]
Repositoriy
# Out:
#                             Repository Title  \
# 0                       plandex-ai / plandex
# 1                      HardhatChad / ore-cli
# 2            PKUFlyingPig / cs-self-learning
# 3                          HardhatChad / ore
# 4                      AstroNvim / AstroNvim
# 5                freeCodeCamp / freeCodeCamp
# 6   EbookFoundation / free-programming-books
# 7                  public-apis / public-apis
# 8                    aurora-develop / aurora
# 9                        myshell-ai / JetMoE
# 10                 ixartz / SaaS-Boilerplate
# 11                          dockur / windows
# 12         kamranahmedse / developer-roadmap
# 13                         searxng / searxng
# 14                       cloudflare / orange
# 15                availproject / avail-light
# 16                           neovim / neovim
# 17                      availproject / avail
# 18                   ossu / computer-science
# 19                    FoundationVision / VAR
# ...

# %% [markdown]
# # Q-3

# %%
driver=webdriver.Chrome()
driver.maximize_window()

# %%
driver.get("http://statisticstimes.com/")
time.sleep(2)

# %%
Economy= driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/button')
Economy.click()
India=driver.find_element(By.XPATH, "/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
driver.get(India.get_attribute('href'))

# %%
GDP_Indian_States=driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
driver.get(GDP_Indian_States.get_attribute('href'))

# %%
Rank=[] 
State=[] 
GSDP_Year_2021_to_Year_2022=[] 
GSDP_Year_2022_to_Year_2023=[] 
Share_Year_2021_to_2022=[] 
GDP_Dollar_Billion=[]

# %%
rank= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td')
for i in rank:
    Rank.append(i.text)
    
state= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td[2]')
for i in state:
    State.append(i.text)
    
    
Gsdp_21_22= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td[5]')
for i in Gsdp_21_22:
    GSDP_Year_2021_to_Year_2022.append(i.text)
    

Gsdp_22_23= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td[4]')
for i in Gsdp_22_23:
    GSDP_Year_2022_to_Year_2023.append(i.text)
    
share= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td[6]')
for i in share:
    Share_Year_2021_to_2022.append(i.text)
    
    
dollar= driver.find_elements(By.XPATH, '//table[@class="display dataTable"]/tbody/tr/td[7]')
for i in dollar:
    GDP_Dollar_Billion.append(i.text)

# %%
print(State)
# Out:
# ['Maharashtra', 'Tamil Nadu', 'Karnataka', 'Uttar Pradesh', 'Gujarat', 'West Bengal', 'Rajasthan', 'Andhra Pradesh', 'Telangana', 'Madhya Pradesh', 'Kerala', 'Delhi', 'Haryana', 'Odisha', 'Bihar', 'Punjab', 'Assam', 'Chhattisgarh', 'Jharkhand', 'Uttarakhand', 'Jammu & Kashmir', 'Himachal Pradesh', 'Goa', 'Tripura', 'Chandigarh', 'Puducherry', 'Meghalaya', 'Sikkim', 'Manipur', 'Arunachal Pradesh', 'Nagaland', 'Mizoram', 'Andaman & Nicobar Islands', 'Maharashtra', 'Tamil Nadu', 'Karnataka', 'Uttar Pradesh', 'Gujarat', 'West Bengal', 'Rajasthan', 'Andhra Pradesh', 'Telangana', 'Madhya Pradesh', 'Kerala', 'Delhi', 'Haryana', 'Bihar', 'Odisha', 'Punjab', 'Assam', 'Chhattisgarh', 'Jharkhand', 'Uttarakhand', 'Jammu & Kashmir', 'Himachal Pradesh', 'Goa', 'Tripura', 'Chandigarh', 'Puducherry', 'Meghalaya', 'Manipur', 'Sikkim', 'Arunachal Pradesh', 'Nagaland', 'Mizoram', 'Andaman & Nicobar Islands', 'Maharashtra', 'Tamil Nadu', 'Karnataka', 'Uttar Pradesh', 'Gujarat', 'West Bengal', 'Rajasthan
# ...

# %%
GSDP=pd.DataFrame({})
GSDP['Rank']=Rank[:33]
GSDP['State']=State[:33]
GSDP['GSDP (Cr INR at Current prices) Year 2021-2022']=GSDP_Year_2021_to_Year_2022[:33] 
GSDP['GSDP (Cr INR at Current prices) Year 2022-2023']=GSDP_Year_2022_to_Year_2023[:33]
GSDP['Share Year 2021-2022']=Share_Year_2021_to_2022[:33]
GSDP['GDP ($ Billion)']=GDP_Dollar_Billion[:33]
GSDP
# Out:
#              Rank                      State  \
# 0               1                Maharashtra
# 1     Maharashtra                 Tamil Nadu
# 2               -                  Karnataka
# 3               -              Uttar Pradesh
# 4       3,108,022                    Gujarat
# 5          13.17%                West Bengal
# 6         414.928                  Rajasthan
# 7               -             Andhra Pradesh
# 8               -                  Telangana
# 9       2,027,971             Madhya Pradesh
# 10              2                     Kerala
# 11     Tamil Nadu                      Delhi
# 12      2,700,109                    Haryana
# 13      2,364,514                     Odisha
# 14      2,071,286                      Bihar
# 15          8.78%                     Punjab
# 16        276.522                      Assam
# 17      1,572,601               Chhattisgarh
# 18      1,453,321                  Jharkhand
# 19      1,343,287                Uttarakhand
# ...
